# %% [markdown]
# ### ライブラリ
#
# - ライブラリとは、再利用しやすいように複数の関数をまとめたもの
# - まずは、mathという様々な数学関数を呼び出せるライブラリを使用

# %%
import math

# %%
# 平方根
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
# モジュールに含まれる関数やクラス、定数などに関する説明や使用方法が表示される
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
# ...

# %% [markdown]
# #### math.関数名のリスト
#
# - math.sin(x) : サイン関数
# - math.cos(x) : コサイン関数
# - math.factorial(x) : 階乗
# - math.sqrt(x): 平方根

# %%
# sin. cos
math.sin(10)
# Out:
# -0.5440211108893698

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
# 3! = 3 × 2 × 1, 階乗
math.factorial(3)
# Out:
# 6

# %%
# 平方根
math.sqrt(10)
# Out:
# 3.1622776601683795

# %% [markdown]
# #### ライブラリの読み込みを短縮する

# %%
# 'm'という名前でライブラリを使用
import math as m
m.sqrt(3)
# Out:
# 1.7320508075688772

# %% [markdown]
# ### ライブラリのインストール
#
# - pip 〇〇で、ライブラリを管理するツールを使用出来る。
# - まずはOSコマンドを(!)で呼び出し、インストールのリストを見る

# %%
# これだけのライブラリがインストールされている
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.5
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# attrs                            23.1.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.13.0
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# ...

# %%
# pip install ○○でライブラリをインストールできる

# %% [markdown]
# ### 便利なライブラリ
#
# - numpy: ベクトルや行列などの数値演算を行うことができる
# - pandas: 表形式のデータを柔軟に操作・処理することができる、エクセル内でできることは代替可能
# - matplotlib, seaborn, plotly: 柔軟な可視化を行うことができる

# %% [markdown]
# #### Numpy

# %%
# asの後のnpは、省略形。今後npで使用できる
import numpy as np

# %%
# 1次元配列の作り方
# listと近い
arr = np.array([1, 2, 3, 4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
# 2次元配列の作り方
# 今回は2行4列の配列を定義
arr2 = np.array([[1, 2, 3, 4], [3, 7, 8, 9]])
print(arr2)
# Out:
# [[1 2 3 4]
#  [3 7 8 9]]

# %%
# .T で転置
arr2.T
# Out:
# array([[1, 3],
#        [2, 7],
#        [3, 8],
#        [4, 9]])

# %%
# 要素のアクセスは、インデックスを指定
arr2[1]
# Out:
# array([3, 7, 8, 9])

# %%
# 例えばarr2[0][0]は1行目の1列目の要素を取得する事になる
arr2[1][2]
# Out:
# 8

# %% [markdown]
# #### Pandas

# %%
# エクセルでできるようなことは Pandas で代替可能
import pandas as pd

# %%
# read_csv の結果を dfという変数に格納
# dfという変数に対して様々な処理が可能

df = pd.read_csv("/content/sample教材.csv")
df
# Out:
#     年齢    趣味   名前
# 0   55   テニス  ヤマダ
# 1   56    野球  マツダ
# 2   57  サッカー  サナダ
# 3   58   バスケ  カナダ
# 4   59   テニス  ヤマダ
# 5   60    野球  マツダ
# 6   61  サッカー  サナダ
# 7   62   バスケ  カナダ
# 8   63   テニス  ヤマダ
# 9   64    野球  マツダ
# 10  65  サッカー  サナダ
# 11  66   バスケ  カナダ
# 12  67   テニス  ヤマダ
# 13  68    野球  マツダ
# 14  69  サッカー  サナダ
# 15  70   バスケ  カナダ
# 16  71   テニス  ヤマダ
# 17  72    野球  マツダ
# 18  73  サッカー  サナダ
# 19  74   バスケ  カナダ

# %%
# numpyと同様にデータの次元を取得できる(20列、3行)
df.shape
# Out:
# (20, 3)

# %%
# 年齢列を抽出
df['年齢']
# Out:
# 0     55
# 1     56
# 2     57
# 3     58
# 4     59
# 5     60
# 6     61
# 7     62
# 8     63
# 9     64
# 10    65
# 11    66
# 12    67
# 13    68
# 14    69
# 15    70
# 16    71
# 17    72
# 18    73
# 19    74
# Name: 年齢, dtype: int64

# %% [markdown]
# * 行番号や列番号を指定して抽出したい場合は、ilocを使う

# %%
# indexが2の行（3行目）の抽出
df.iloc[2]
# Out:
# 年齢      57
# 趣味    サッカー
# 名前     サナダ
# Name: 2, dtype: object

# %%
# indexが2の行以降（3行目以降）の抽出
df.iloc[2:]
# Out:
#     年齢    趣味   名前
# 2   57  サッカー  サナダ
# 3   58   バスケ  カナダ
# 4   59   テニス  ヤマダ
# 5   60    野球  マツダ
# 6   61  サッカー  サナダ
# 7   62   バスケ  カナダ
# 8   63   テニス  ヤマダ
# 9   64    野球  マツダ
# 10  65  サッカー  サナダ
# 11  66   バスケ  カナダ
# 12  67   テニス  ヤマダ
# 13  68    野球  マツダ
# 14  69  サッカー  サナダ
# 15  70   バスケ  カナダ
# 16  71   テニス  ヤマダ
# 17  72    野球  マツダ
# 18  73  サッカー  サナダ
# 19  74   バスケ  カナダ

# %%
# 2列目2行目をピックアップ。0、0で1列目1行目
df.iloc[1, 1]
# Out:
# '野球'

# %%
# 3行目～6行目の1列目～2列目を取得
df.iloc[2:6, 0:2]
# Out:
#    年齢    趣味
# 2  57  サッカー
# 3  58   バスケ
# 4  59   テニス
# 5  60    野球

# %% [markdown]
# *   describe()⇒各カラムの平均値や標準誤差、四分位数といった基礎統計量を求めることができる
# *   to_csv(): csvファイル形式での保存ができる
# *   リスト項目

# %%
df['年齢'].mean()
# Out:
# 64.5

# %%
df['年齢'].sum()
# Out:
# 1290

# %%
df.describe()
# Out:
#              年齢
# count  20.00000
# mean   64.50000
# std     5.91608
# min    55.00000
# 25%    59.75000
# 50%    64.50000
# 75%    69.25000
# max    74.00000

# %%
# 新しい df2という変数に代入
df2 = df.describe()
df2
# Out:
#              年齢
# count  20.00000
# mean   64.50000
# std     5.91608
# min    55.00000
# 25%    59.75000
# 50%    64.50000
# 75%    69.25000
# max    74.00000

# %%
# dfはデータフレーム
# データの保存
df2.to_csv('sample教材2.csv')

# %% [markdown]
# - plot(): 様々なグラフを作成することができる

# %%
# 日本語のグラフを表示するための設定
# !pip install japanize-matplotlib
import japanize_matplotlib
from matplotlib import pyplot as plt

# %%
df.plot() # 各列の折れ線グラフ
plt.savefig("sample教材.png") # savefig("ファイル名")で任意の名前でグラフ画像を保存することができる

# 年齢欄にしか数値が無いので一つだけ表示される

# %%
# figsize でグラフサイズを指定
df.plot(figsize=(5, 5)) # 大きさを自由に変更出来る
plt.savefig("sample教材2.png") # ファイル名をつける

# %%
# read_csv の結果を dfbという変数に格納
# dfbという変数に対して様々な処理が可能

dfb = pd.read_csv("/content/sample教材強化版.csv")
dfb
# Out:
#     年齢    趣味   名前  50m走  食事の時間(分)  反復横跳び
# 0   55   テニス  ヤマダ  1100        69     12
# 1   56    野球  マツダ  1101        39      3
# 2   57  サッカー  サナダ  1102        20     44
# 3   58   バスケ  カナダ  1103        59     55
# 4   59   テニス  ヤマダ  1104        40     22
# 5   60    野球  マツダ  1105       320     11
# 6   61  サッカー  サナダ   906       204     11
# 7   62   バスケ  カナダ  1107         3     90
# 8   63   テニス  ヤマダ  1108         9  10000
# 9   64    野球  マツダ  1109        10      2
# 10  65  サッカー  サナダ  1110      1000      2
# 11  66   バスケ  カナダ   701        49     34
# 12  67   テニス  ヤマダ  1112        50     44
# 13  68    野球  マツダ  1113        51     53
# 14  69  サッカー  サナダ  1114        52     54
# 15  70   バスケ  カナダ  1115        53     55
# 16  71   テニス  ヤマダ  1006        54     56
# 17  72    野球  マツダ  1117        55     57
# 18  73  サッカー  サナダ  1118        56     58
# 19  74   バスケ  カナダ   809        57     59

# %%
# 全列を可視化出来るが、数値の記述が1列しかないので貧相です。なので強化版を作成しました。
dfb.plot(subplots=True, figsize=(13, 5)) # subplots=Trueとすると、一つのグラフではなく別々のグラフを生成される
plt.savefig("Sample教材3.png")
