# %% [markdown]
# ## 複数のデータをまとめて格納する変数
#
# - リスト
#   - **順番を保持したまま複数の数値や文字列(テキスト)を入れられる箱**
#   - 複数の値を[ ]で囲むことによって、リストを作成することができる
# - タプル
#   - リストと違い、タプルでは()で囲むことで定義する
#   - リストとの大きな違いとして、タプルの要素は変更できない
# - 辞書
#   - 辞書は、keyとvalueをセットにしたデータ構造を持つ
#   - 辞書型の変数を作るには、{}で値を定義する

# %% [markdown]
# ### リスト

# %%
# 10, 20, 30, 40, 50 という5つのデータを一つのa_list という変数に格納することができる
a_list = [10, 20, 30, 40, 50]

# %%
a_list
# Out:
# [10, 20, 30, 40, 50]

# %%
# 最初の値を取得
a_list [0]
# Out:
# 10

# %%
# 4番目以降（4番目と5番目）の値を取得
a_list [3]
# Out:
# [40, 50]

# %% [markdown]
# #### 値の変更

# %%
num_list = [10, 20, 30, 40, 50]

# %%
num_list
# Out:
# [10, 20, 30, 40, 50]

# %%
num_list[2] = 100

# %%
num_list
# Out:
# [10, 20, 100, 40, 50]

# %% [markdown]
# ### タプル

# %%
num_list = [0, 1, 8, 12]
num_tuple = (0, 1, 8, 12)

# %%
num_list
# Out:
# [0, 1, 8, 12]

# %%
num_tuple
# Out:
# (0, 1, 8, 12)

# %%
num_list[2] = 100
num_list
# Out:
# [0, 1, 100, 12]

# %%
num_tuple[2] = 100  #タプルは設定したものを変更できない
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-776d600aadbf> in <cell line: 1>()
# ----> 1 num_tuple[2] = 100  #タプルは設定したものを変更できない
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 辞書

# %%
# 'a'がkey, 20がvalue
# 'b'がkey, 30がvalue
# 'c'がkey, 15がvalue

tmp_dict = {'a': 20, 'b': 30, 'c': 15}

# %% [markdown]
# - keyとvalueはセットになっているため、keyを指定することによってvalueを取り出すことができる

# %%
tmp_dict['a']
# Out:
# 20

# %%
tmp_dict['b']
# Out:
# 30

# %%
tmp_dict['c']
# Out:
# 15

# %%
tmp_dict['d'] #存在しないkeyはエラーに
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-7cc7eb7cf634> in <cell line: 1>()
# ----> 1 tmp_dict['d'] #存在しないkeyはエラーに
#
# KeyError: 'd'

# %% [markdown]
# - keys()メソッドを使うことで、keyの一覧を取得することができる
# - values()メソッドを使うことで、valueの一覧を取得することができる

# %%
tmp_dict.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
tmp_dict.values()
# Out:
# dict_values([20, 30, 15])

# %% [markdown]
# # クラスとオブジェクト

# %% [markdown]
# ## シンプルなクラス

# %%
class ExercisePerson():
    def __init__(self, name):
        print("初期化メソッドが実行されました")
        self.name = name # name という情報を持つクラス

# %%
person1 = ExercisePerson("Ken")
# Out:
# 初期化メソッドが実行されました

# %%
person1.name
# Out:
# 'Ken'

# %%
person2 = ExercisePerson("Emi")
# Out:
# 初期化メソッドが実行されました

# %%
person2.name
# Out:
# 'Emi'

# %% [markdown]
# ## インスタンス変数を追加

# %%
class ExercisePerson():
    def __init__(self, name, weight):
        print("初期化メソッドが実行されました")
        self.name = name
        self.weight = weight # weightという情報を追加

# %%
person1 = ExercisePerson("Ken", 100)
person2 = ExercisePerson("Emi", 50)
# Out:
# 初期化メソッドが実行されました
# 初期化メソッドが実行されました

# %%
print(person2.name)
print(person2.weight)
# Out:
# Emi
# 50

# %%
print(person1.name)
print(person1.weight)
# Out:
# Ken
# 100
